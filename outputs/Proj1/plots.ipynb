# %%
import pickle
import sys
import seaborn as sns

sys.path.insert(0, '../../Proj1')

sns.set_style("whitegrid")
from plot import plot_stats

# %%
stats_df = pickle.load(open('stats_df.p', 'rb'))
plot_stats(stats_df, 'svg', (10,4))
