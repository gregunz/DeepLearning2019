# %%
import pickle
import pandas as pd

# %%
stats_df = pickle.load(open('stats_df.p', 'rb'))

# %%
stats_df['phase'].unique()
# Out:
# array(['train', 'test'], dtype=object)

# %%
stats_df
# Out:
#          acc epoch       loss   model  phase
# 0   0.586914     0  30.030010      FC  train
# 1   0.723633     1  17.396687      FC  train
# 2   0.777344     2  14.474849      FC  train
# 3   0.808594     3  12.508144      FC  train
# 4   0.834961     4  11.487070      FC  train
# 5   0.856445     5  10.073682      FC  train
# 6   0.880859     6   8.941573      FC  train
# 7   0.891602     7   8.132918      FC  train
# 8   0.896484     8   7.733688      FC  train
# 9   0.914062     9   6.452883      FC  train
# 10  0.930664    10   6.078652      FC  train
# 11  0.938477    11   5.391164      FC  train
# 12  0.945312    12   4.711574      FC  train
# 13  0.946289    13   4.487458      FC  train
# 14  0.954102    14   4.194018      FC  train
# 15  0.957031    15   4.112845      FC  train
# 16  0.965820    16   3.559361      FC  train
# 17  0.969727    17   3.373022      FC  train
# 18  0.963867    18   2.986027      FC  train
# 19  0.979492    19   2.300898      FC  train
# 20  0.989258    20   1.904569      FC  train
# 21  0.989258    21   1.615588      FC  train
# 22  0.988281    22   1.639966      FC  train
# 23  0.993164    23   1.362419      FC  train
# 24  0.996094    24   1.079265      FC  train
# 25  0.997070    25   0.930549      FC  train
# 26  0.999023    26   0.747188      FC  train
# 27  0.999023    27   0.661532      FC  train
# 28  1.000000    28   0.566471      FC  train
# 29  1.000000    29   0.516752      FC  train
# ..       ...   ...        ...     ...    ...
# 70  0.795898    70  17.970610  FC_aux   test
# 71  0.786133    71  19.126741  FC_aux   test
# 72  0.800781    72  17.878119  FC_aux   test
# 73  0.792969    73  18.666933  FC_aux   test
# 74  0.801758    74  18.185089  FC_aux   test
# 75  0.795898    75  19.125954  FC_aux   test
# 76  0.798828    76  18.274836  FC_aux   test
# 77  0.804688    77  18.269957  FC_aux   test
# 78  0.800781    78  18.568398  FC_aux   test
# 79  0.804688    79  19.020084  FC_aux   test
# 80  0.790039    80  19.039091  FC_aux   test
# 81  0.805664    81  19.373354  FC_aux   test
# 82  0.796875    82  19.562147  FC_aux   test
# 83  0.805664    83  19.534853  FC_aux   test
# 84  0.795898    84  20.155891  FC_aux   test
# 85  0.799805    85  19.543169  FC_aux   test
# 86  0.800781    86  20.928970  FC_aux   test
# 87  0.807617    87  21.939327  FC_aux   test
# 88  0.808594    88  20.487808  FC_aux   test
# 89  0.808594    89  21.409058  FC_aux   test
# 90  0.815430    90  21.688898  FC_aux   test
# 91  0.806641    91  22.008410  FC_aux   test
# 92  0.802734    92  20.969105  FC_aux   test
# 93  0.809570    93  22.510235  FC_aux   test
# 94  0.806641    94  21.757591  FC_aux   test
# 95  0.812500    95  21.891226  FC_aux   test
# 96  0.811523    96  21.530540  FC_aux   test
# 97  0.811523    97  20.988100  FC_aux   test
# 98  0.810547    98  21.908127  FC_aux   test
# 99  0.809570    99  23.440029  FC_aux   test
#
# [2000 rows x 5 columns]

# %%
import sys

sys.path.insert(0, '../../Proj1')
from plot import plot_stats

# %%
plot_stats(stats_df)
